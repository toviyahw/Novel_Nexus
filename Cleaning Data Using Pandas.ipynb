# %% [markdown]
# # **Cleaning Initial Excel Datasets**

# %% [markdown]
# After manually inputting my data into Excel sheets, I used the pandas library to check for duplicates and any NULL values. Because all of my files are separated into what will be normalized SQL tables, there can be neither.
#
# I am also changing the configuration of IPython interactive shell from the default 'last_expr' to 'all' so that I can see the outputs of all of my expressions instead of just the final one.

# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" #prints all commands

# %%
#authors table

df = pd.read_csv('authors_data.csv')

df.head()
df.isnull().sum()

num_of_duplicates = df.duplicated().sum()
print (f'This dataset contains {num_of_duplicates} duplicates.')
# Out:
#    book_id                         title            author_name
# 0        1     Apprentice to the Villain  Hannah Nicole Maehrer
# 1        2               The Rom-Commers       Katherine Center
# 2        3            Two Twisted Crowns          Rachel Gillig
# 3        4  You Shouldn't Have Come Here            Jeneva Rose
# 4        5                 The Awakening       Caroline Peckham
# book_id        0
# title          0
# author_name    0
# dtype: int64
# This dataset contains 0 duplicates.

# %%
#books table

df = pd.read_csv('books_data.csv')

df.head()
df.isnull().sum()

num_of_duplicates = df.duplicated().sum()
print (f'This dataset contains {num_of_duplicates} duplicates.')
# Out:
#    book_id                         title           isbn  page_count  \
# 0        1     Apprentice to the Villain     B0DBJ56PPZ         NaN
# 1        2               The Rom-Commers  9781250344793         NaN
# 2        3            Two Twisted Crowns  9780356519500       437.0
# 3        4  You Shouldn't Have Come Here     B0DLT3HSHM         NaN
# 4        5                 The Awakening     B0947FLX32         NaN
#
#    year_published
# 0            2024
# 1            2024
# 2            2023
# 3            2023
# 4            2019
# book_id            0
# title              0
# isbn               0
# page_count        14
# year_published     0
# dtype: int64
# This dataset contains 0 duplicates.

# %% [markdown]
# Here, the **page_count** column has 14 NULL values. These NULL values represent books I have read that have no pages, in other words, the audiobooks. To resolve this, I will replace all NULL values here with 0.

# %%
df.fillna(0, inplace= True)

# %% [markdown]
# Now all of my page count values that were previously NULL have been assigned a value of 0.

# %%
#date_read table

df = pd.read_csv('date_read_data.csv')

df.head()
df.isnull().sum()

num_of_duplicates = df.duplicated().sum()
print (f'This dataset contains {num_of_duplicates} duplicates.')
# Out:
#    book_id                         title  year_published  start_date  \
# 0        1     Apprentice to the Villain            2024  2024-11-30
# 1        2               The Rom-Commers            2024  2024-11-27
# 2        3            Two Twisted Crowns            2023  2024-11-25
# 3        4  You Shouldn't Have Come Here            2023  2024-02-19
# 4        5                 The Awakening            2019  2024-11-26
#
#      end_date
# 0  2024-12-12
# 1  2024-22-30
# 2  2024-11-28
# 3  2024-02-19
# 4  2024-11-27
# book_id           0
# title             0
# year_published    0
# start_date        0
# end_date          0
# dtype: int64
# This dataset contains 0 duplicates.

# %%
#format table

df = pd.read_csv('format_data.csv')

df.head()
df.isnull().sum()

num_of_duplicates = df.duplicated().sum()
print (f'This dataset contains {num_of_duplicates} duplicates.')
# Out:
#    book_id book_format
# 0        1       audio
# 1        2       audio
# 2        3   paperback
# 3        4       audio
# 4        5       audio
# book_id        0
# book_format    0
# dtype: int64
# This dataset contains 0 duplicates.

# %%
#genres table

df = pd.read_csv('genres_data.csv')

df.head()
df.isnull().sum()

num_of_duplicates = df.duplicated().sum()
print (f'This dataset contains {num_of_duplicates} duplicates.')
# Out:
#    book_id                         title      genre
# 0        1     Apprentice to the Villain  romantasy
# 1        2               The Rom-Commers     romcom
# 2        3            Two Twisted Crowns  romantasy
# 3        3            Two Twisted Crowns     gothic
# 4        4  You Shouldn't Have Come Here    mystery
# book_id    0
# title      0
# genre      0
# dtype: int64
# This dataset contains 0 duplicates.

# %%
#gr_scores table

df = pd.read_csv('grscores_data.csv')

df.head()
df.isnull().sum()

num_of_duplicates = df.duplicated().sum()
print (f'This dataset contains {num_of_duplicates} duplicates.')
# Out:
#    book_id                         title calc_score calc_gr_score  \
# 0        1     Apprentice to the Villain     37.14%        83.00%
# 1        2               The Rom-Commers     74.29%        82.20%
# 2        3            Two Twisted Crowns     85.71%        88.40%
# 3        4  You Shouldn't Have Come Here     34.29%        66.80%
# 4        5                 The Awakening     62.86%        77.00%
#
#    avg_gr_rating
# 0           4.15
# 1           4.11
# 2           4.42
# 3           3.34
# 4           3.85
# book_id          0
# title            0
# calc_score       0
# calc_gr_score    0
# avg_gr_rating    0
# dtype: int64
# This dataset contains 0 duplicates.

# %%
#my_library table

df = pd.read_csv('library_data.csv')

df.head()
df.isnull().sum()

num_of_duplicates = df.duplicated().sum()
print (f'This dataset contains {num_of_duplicates} duplicates.')
# Out:
#    library_id  book_id                title  price           isbn
# 0           1      3.0   Two Twisted Crowns  14.24  9780316312714
# 1           2      7.0        Sharp Objects   4.99  9780307341556
# 2           3      8.0      One Dark Window  14.94  9780316312486
# 3           4      9.0        The Housemaid   8.11  9781538742570
# 4           5     10.0  Behind Closed Doors   7.48  9781250132369
# library_id     0
# book_id       90
# title          0
# price          0
# isbn           0
# dtype: int64
# This dataset contains 0 duplicates.

# %%
#ratings table

df = pd.read_csv('ratings_data.csv')

df.head()
df.isnull().sum()

num_of_duplicates = df.duplicated().sum()
print (f'This dataset contains {num_of_duplicates} duplicates.')
# Out:
#    book_id                         title  plot  writing  pacing  personages  \
# 0        1     Apprentice to the Villain     3        3       3           2
# 1        2               The Rom-Commers     4        5       5           5
# 2        3            Two Twisted Crowns     5        4       4           5
# 3        4  You Shouldn't Have Come Here     2        3       2           2
# 4        5                 The Awakening     4        2       4           3
#
#    impact  rereadability  immersivity  overall_score calculated_score
# 0       0              0            2             13           37.14%
# 1       3              2            2             26           74.29%
# 2       4              3            5             30           85.71%
# 3       0              0            3             12           34.29%
# 4       3              3            3             22           62.86%
# book_id             0
# title               0
# plot                0
# writing             0
# pacing              0
# personages          0
# impact              0
# rereadability       0
# immersivity         0
# overall_score       0
# calculated_score    0
# dtype: int64
# This dataset contains 0 duplicates.

# %%
#series table

df = pd.read_csv('series_data.csv')

df.head()
df.isnull().sum()

num_of_duplicates = df.duplicated().sum()
print (f'This dataset contains {num_of_duplicates} duplicates.')
# Out:
#    book_id                         title      genre
# 0        1     Apprentice to the Villain  romantasy
# 1        2               The Rom-Commers     romcom
# 2        3            Two Twisted Crowns  romantasy
# 3        3            Two Twisted Crowns     gothic
# 4        4  You Shouldn't Have Come Here    mystery
# book_id    0
# title      0
# genre      0
# dtype: int64
# This dataset contains 0 duplicates.

# %% [markdown]
# Now that I have handled the NULL values and confirmed that my dataset is free of duplicates, I can begin creating my tables using postgreSQL with clean datasets.
